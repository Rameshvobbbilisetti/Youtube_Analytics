# %%
from googleapiclient.discovery import build
import pandas  as pd
import seaborn as sns
import matplotlib.pyplot as plt
from isodate import parse_duration

# %%
api_key = ['AIzaSyCqNmQ1igU-2AGWK1S2bxkB5KI7_2zhfGU']
channel_ids = ['UCh9nVJoWXmFb7sLApWGcLPQ','UC61Y04JVLkByFRv1K3V-KGQ','UCnz-ZXXER4jOvuED5trXfEA','UCk7NcgnqCmui1AV7MTXZwOw']

# %%
youtube = build('youtube','v3',developerKey=api_key)

# %% [markdown]
# ##Function to get Channel Statistics

# %%
def get_channel_stats(youtube,channel_id):
  all_data = []
  request = youtube.channels().list(
        part="snippet,contentDetails,statistics",
        id=','.join(channel_ids)
    )
  response = request.execute()
  for i in range(len(response['items'])):
    data = dict(channel_name = response['items'][i]['snippet']['title'],
         Subscribers_count = response['items'][i]['statistics']['subscriberCount'],
         Views_count = response['items'][i]['statistics']['viewCount'],
         Videos_count = response['items'][i]['statistics']['videoCount'],
         Playlist_id = response['items'][i]['contentDetails']['relatedPlaylists']['uploads'])

    all_data.append(data)

  return all_data

# %%
channel_statistics = get_channel_stats(youtube,channel_ids)

# %%
channel_data = pd.DataFrame(channel_statistics)

# %%
channel_data
# Out:
#       channel_name Subscribers_count Views_count Videos_count  \
# 0     Ankit Bansal             85100     3193197          162
# 1          techTFQ            272000    14579748          104
# 2       codebasics            948000    68751296          809
# 3  Analyst Adithya              8190      160298          202
#
#                 Playlist_id
# 0  UUk7NcgnqCmui1AV7MTXZwOw
# 1  UUnz-ZXXER4jOvuED5trXfEA
# 2  UUh9nVJoWXmFb7sLApWGcLPQ
# 3  UU61Y04JVLkByFRv1K3V-KGQ

# %%
channel_data['Subscribers_count'] = pd.to_numeric(channel_data['Subscribers_count'])
channel_data['Views_count'] = pd.to_numeric(channel_data['Views_count'])
channel_data['Videos_count'] = pd.to_numeric(channel_data['Videos_count'])

# %%
ax = sns.barplot(x='channel_name', y='Subscribers_count', data = channel_data)

# %% [markdown]
# ##Function to get Video Ids

# %%
playlist_id = channel_data.loc[channel_data['channel_name'] == 'codebasics', 'Playlist_id'].values

# %%
playlist_id = playlist_id[0]

# %%
playlist_id
# Out:
# 'UUh9nVJoWXmFb7sLApWGcLPQ'

# %%
def get_video_ids(youtube, playlist_id):

    request = youtube.playlistItems().list(
                part='contentDetails',
                playlistId = playlist_id,
                maxResults = 50)
    response = request.execute()

    video_ids = []

    for i in range(len(response['items'])):
        video_ids.append(response['items'][i]['contentDetails']['videoId'])

    next_page_token = response.get('nextPageToken')
    more_pages = True

    while more_pages:
        if next_page_token is None:
            more_pages = False
        else:
            request = youtube.playlistItems().list(
                        part='contentDetails',
                        playlistId = playlist_id,
                        maxResults = 50,
                        pageToken = next_page_token)
            response = request.execute()

            for i in range(len(response['items'])):
                video_ids.append(response['items'][i]['contentDetails']['videoId'])

            next_page_token = response.get('nextPageToken')

    return video_ids

# %%
video_ids = get_video_ids (youtube,playlist_id )

# %%
len(video_ids)
# Out:
# 809

# %% [markdown]
# ##Function to get Video Details

# %%
def video_details(youtube, video_ids):
    all_video_stats = []

    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=','.join(video_ids[i:i+50])
        )
        response = request.execute()

        for video in response['items']:
            video_stats = {
                'Title': video['snippet']['title'],
                'Published_at': video['snippet']['publishedAt'],
                'Views_count': video['statistics']['viewCount'],
                'Likes_count': video['statistics']['likeCount'],
                'Comments_count': video['statistics']['commentCount'],
                'Duration': video['contentDetails']['duration']
            }

            # Check if 'tags' key exists in the snippet
            if 'tags' in video['snippet']:
                video_stats['Tags'] = video['snippet']['tags']
            else:
                video_stats['Tags'] = None

            all_video_stats.append(video_stats)

    return all_video_stats

# %%
video_details= video_details(youtube, video_ids)

# %%
video_data = pd.DataFrame(video_details)

# %%
video_data
# Out:
#                                               Title          Published_at  \
# 0    AI Engineer Roadmap | How I'd Learn AI in 2024  2024-02-22T13:30:11Z
# 1                    Reality of Data Analysts Role!  2024-02-22T12:30:26Z
# 2            Lawyer to Software Engineer at Google!  2024-02-21T12:30:33Z
# 3         9 Unguided data projects for your Resume!  2024-02-19T12:30:35Z
# 4                                   Is Python SLOW?  2024-02-15T12:30:11Z
# ..                                              ...                   ...
# 804                      Python Tutorial - 5. Lists  2015-12-20T23:01:51Z
# 805                    Python Tutorial - 4. Strings  2015-12-20T22:34:19Z
# 806                    Python Tutorial - 3. Numbers  2015-12-20T02:54:56Z
# 807                  Python Tutorial - 2. Variables  2015-12-20T02:11:10Z
# 808  Python Tutorial - 1. Install python on windows  2015-12-20T01:21:07Z
#
#     Views_count Likes_count Comments_count  Duration  \
# ...

# %% [markdown]
# ##Data Preprocessing

# %%
video_data.head()
# Out:
#                                             Title          Published_at  \
# 0  AI Engineer Roadmap | How I'd Learn AI in 2024  2024-02-22T13:30:11Z
# 1                  Reality of Data Analysts Role!  2024-02-22T12:30:26Z
# 2          Lawyer to Software Engineer at Google!  2024-02-21T12:30:33Z
# 3       9 Unguided data projects for your Resume!  2024-02-19T12:30:35Z
# 4                                 Is Python SLOW?  2024-02-15T12:30:11Z
#
#   Views_count Likes_count Comments_count  Duration  \
# 0       18368        1051            104  PT30M41S
# 1        5894         513             14     PT49S
# 2        3159         140              5     PT53S
# 3        3107         252              4     PT32S
# 4       10080         482             19     PT48S
#
#                                                 Tags
# 0  [ai engineering, ai career, career in ai, ai m...
# 1                                               None
# 2                                               None
# ...

# %%
video_data.dtypes
# Out:
# Title             object
# Published_at      object
# Views_count       object
# Likes_count       object
# Comments_count    object
# Duration          object
# Tags              object
# dtype: object

# %%
video_data['Views_count'] = pd.to_numeric(video_data['Views_count'])
video_data['Likes_count'] = pd.to_numeric(video_data['Likes_count'])
video_data['Comments_count'] = pd.to_numeric(video_data['Comments_count'])
video_data['Published_at'] = pd.to_datetime(video_data['Published_at'])
video_data['durationSecs']= video_data['Duration'].apply(lambda x: parse_duration(x))
video_data['durationSecs']=video_data['durationSecs'].astype('timedelta64[s]')
video_data['Published_at'] =pd.to_datetime(video_data['Published_at']).dt.date

# %%
video_data.drop('Duration',axis=1,inplace=True)

# %%
video_data['tagcount']= video_data['Tags'].apply(lambda x: 0 if x is None else len(x))

# %%
video_data.drop('Tags',axis=1,inplace=True)

# %%
video_data['Published_Day'] = video_data['Published_at'].apply(lambda x: x.strftime("%A"))

# %%
video_data['video_type'] = video_data['tagcount'].apply(lambda x: 'Shorts' if x == 0 else 'Normal_Video')

# %%
video_data.head()
# Out:
#                                             Title Published_at  Views_count  \
# 0  AI Engineer Roadmap | How I'd Learn AI in 2024   2024-02-22        18368
# 1                  Reality of Data Analysts Role!   2024-02-22         5894
# 2          Lawyer to Software Engineer at Google!   2024-02-21         3159
# 3       9 Unguided data projects for your Resume!   2024-02-19         3107
# 4                                 Is Python SLOW?   2024-02-15        10080
#
#    Likes_count  Comments_count  durationSecs  tagcount Published_Day  \
# 0         1051             104        1841.0        13      Thursday
# 1          513              14          49.0         0      Thursday
# 2          140               5          53.0         0     Wednesday
# 3          252               4          32.0         0        Monday
# 4          482              19          48.0         0      Thursday
#
#      video_type
# 0  Normal_Video
# 1        Shorts
# 2        Shorts
# 3        Shorts
# ...

# %% [markdown]
# ##EDA

# %% [markdown]
# ###Views Anlaysis

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ####Top Performing Videos

# %%
Top_10 = video_data.sort_values(by='Views_count', ascending = False).head(10)

# %%
Top_10
# Out:
#                                                  Title Published_at  \
# 338  Reality behind data science, machine learning ...   2022-02-16
# 486  Bitcoin Mining Fundamentals in Python | Python...   2021-01-03
# 737  Python Pandas Tutorial 1. What is Pandas pytho...   2017-01-21
# 706  Machine Learning Tutorial Python -1: What is M...   2018-06-30
# 705  Machine Learning Tutorial Python - 2: Linear R...   2018-07-01
# 557  Complete python roadmap | How to become an exp...   2020-09-13
# 543  Simple explanation of convolutional neural net...   2020-10-14
# 641  Data Structures & Algorithms Tutorial in Pytho...   2020-03-07
# 736         Python Pandas Tutorial 2: Dataframe Basics   2017-01-28
# 734  Python Pandas Tutorial 4: Read Write Excel CSV...   2017-02-04
#
#      Views_count  Likes_count  Comments_count  durationSecs  tagcount  \
# 338      1500912        67400             480          53.0        20
# 486      1102376        31791            2670        1500.0        22
# ...

# %%
ax = sns.barplot(y='Title', x= 'Views_count', data = Top_10)

# %% [markdown]
# ####Least Performing Videos

# %%
least_10 = video_data.sort_values(by='Views_count', ascending = True).head(10)

# %%
least_10
# Out:
#                                                  Title Published_at  \
# 617  Career guidance, job tips with Amazon Engineer...   2020-05-26
# 275                         Teachers Who Influenced us   2022-09-05
# 632  100K subscribers. Thanks For Your Support & Love!   2020-04-15
# 725  5000 subscribers: Recap on channel history and...   2017-06-27
# 646               Codebasics Live Q & A - Feb 19, 2020   2020-02-19
# 27                              Hyderabad Meetup 2024!   2024-01-13
# 544     How to ask technical questions in a right way?   2020-10-11
# 65                              Which BI Tool to pick?   2023-12-09
# 10                   10Km Run to Spread Scam Awarness!   2024-02-05
# 645             Feb 22, 2020: Live Q&A With Codebasics   2020-02-22
#
#      Views_count  Likes_count  Comments_count  durationSecs  tagcount  \
# 617         1136           39              10        2797.0         7
# 275         1286           48               5        1434.0         8
# ...

# %%
ax = sns.barplot(x='Views_count',y='Title', data = least_10)

# %% [markdown]
# #### Distribution of Views between Normal Videos and Shorts

# %%
comparison = video_data.groupby(['video_type'])['Views_count'].sum()

# %%
plt.pie(comparsion['Views_count'], labels=comparsion['video_type'], autopct='%1.1f%%', startangle=90)
plt.title('Share of Total Views Between Normal Videos and Shorts')
plt.show()

# %% [markdown]
# ### Engagement Analysis

# %% [markdown]
# #### Comparison of Views and Likes between Normal videos and shorts

# %%
video_data.head()
# Out:
#                                             Title Published_at  Views_count  \
# 0  AI Engineer Roadmap | How I'd Learn AI in 2024   2024-02-22        18368
# 1                  Reality of Data Analysts Role!   2024-02-22         5894
# 2          Lawyer to Software Engineer at Google!   2024-02-21         3159
# 3       9 Unguided data projects for your Resume!   2024-02-19         3107
# 4                                 Is Python SLOW?   2024-02-15        10080
#
#    Likes_count  Comments_count  durationSecs  tagcount Published_Day  \
# 0         1051             104        1841.0        13      Thursday
# 1          513              14          49.0         0      Thursday
# 2          140               5          53.0         0     Wednesday
# 3          252               4          32.0         0        Monday
# 4          482              19          48.0         0      Thursday
#
#      video_type  Engagement_rate
# 0  Normal_Video         0.057219
# ...

# %%
comparsion = video_data.groupby('video_type')[['Views_count','Likes_count']].sum().reset_index()

# %%
comparsion.plot(kind='bar', x='video_type', y=['Views_count', 'Likes_count'])
plt.title('Comparison of Views and Likes Between Normal Videos and Shorts')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ####Engagement Rate Comparison:

# %%
comparsion['Engagement_rate'] = comparsion['Likes_count'] / comparsion['Views_count']

# Bar chart for engagement rate
comparsion.plot(kind='bar', x='video_type', y='Engagement_rate')
plt.title('Engagement Rate Comparison Between Normal Videos and Shorts')
plt.ylabel('Engagement Rate (Likes per View)')
plt.show()

# %% [markdown]
# ####Videos with Highest Engagement Rate

# %%
video_data.head()
# Out:
#                                             Title Published_at  Views_count  \
# 0  AI Engineer Roadmap | How I'd Learn AI in 2024   2024-02-22        18368
# 1                  Reality of Data Analysts Role!   2024-02-22         5894
# 2          Lawyer to Software Engineer at Google!   2024-02-21         3159
# 3       9 Unguided data projects for your Resume!   2024-02-19         3107
# 4                                 Is Python SLOW?   2024-02-15        10080
#
#    Likes_count  Comments_count  durationSecs  tagcount Published_Day  \
# 0         1051             104        1841.0        13      Thursday
# 1          513              14          49.0         0      Thursday
# 2          140               5          53.0         0     Wednesday
# 3          252               4          32.0         0        Monday
# 4          482              19          48.0         0      Thursday
#
#      video_type
# 0  Normal_Video
# 1        Shorts
# 2        Shorts
# 3        Shorts
# ...

# %%
video_data['Engagement_rate'] = video_data['Likes_count'] / video_data['Views_count']

# %%
top_10 = video_data.sort_values(by='Engagement_rate', ascending=False)[:10]

# %%
ax =sns.barplot(x='Engagement_rate', y='Title', data=top_10)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 129327 (\N{SHOCKED FACE WITH EXPLODING HEAD}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128253 (\N{FILM PROJECTOR}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 129321 (\N{GRINNING FACE WITH STAR EYES}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 127775 (\N{GLOWING STAR}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9989 (\N{WHITE HEAVY CHECK MARK}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %% [markdown]
# ### Correlation Analysis

# %% [markdown]
# #### Views vs Likes

# %%
ax = sns.scatterplot(x='Views_count', y='Likes_count', data = video_data)

# %% [markdown]
# #### Views vs Comments

# %%
ax = sns.scatterplot(x='Views_count', y='Comments_count', data = video_data)

# %% [markdown]
# ####Views vs TagsCount

# %%
ax = sns.scatterplot(y='Views_count', x='tagcount', data = video_data)

# %% [markdown]
# #### Views vs Duration

# %%
ax = sns.scatterplot(y='Views_count', x='durationSecs', data=video_data)

# %% [markdown]
# ###Day-of-week Analysis

# %%
video_data.head()
# Out:
#                                             Title Published_at  Views_count  \
# 0  AI Engineer Roadmap | How I'd Learn AI in 2024   2024-02-22        18368
# 1                  Reality of Data Analysts Role!   2024-02-22         5894
# 2          Lawyer to Software Engineer at Google!   2024-02-21         3159
# 3       9 Unguided data projects for your Resume!   2024-02-19         3107
# 4                                 Is Python SLOW?   2024-02-15        10080
#
#    Likes_count  Comments_count  durationSecs  tagcount Published_Day  \
# 0         1051             104        1841.0        13      Thursday
# 1          513              14          49.0         0      Thursday
# 2          140               5          53.0         0     Wednesday
# 3          252               4          32.0         0        Monday
# 4          482              19          48.0         0      Thursday
#
#      video_type  Engagement_rate
# 0  Normal_Video         0.057219
# ...

# %%
day_of_week_stats = video_data.groupby('Published_Day').agg({
    'Views_count': 'mean',
    'Likes_count': 'mean',
    'Comments_count': 'mean'
}).reset_index()

ordered_days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
day_of_week_stats['Day_of_week'] = pd.Categorical(day_of_week_stats['Published_Day'], categories=ordered_days, ordered=True)
day_of_week_stats = day_of_week_stats.sort_values('Published_Day')

plt.figure(figsize=(12, 6))
sns.barplot(x='Published_Day', y='Views_count', data=day_of_week_stats, label='Average Views', color='skyblue')
sns.barplot(x='Published_Day', y='Likes_count', data=day_of_week_stats, label='Average Likes', color='orange')
sns.barplot(x='Published_Day', y='Comments_count', data=day_of_week_stats, label='Average Comments', color='green')

plt.title('Average Views, Likes, and Comments by Day of the Week')
plt.xlabel('Day of the Week')
plt.ylabel('Average Count')
plt.legend()
plt.show()

# %% [markdown]
# ### Insights

# %% [markdown]
# 1.Videos related to machine learning and Python receive more views, indicating a strong interest in these topics among the audience.
#
# 2.Majority of the views come from normal videos compared to shorts. This trend might be influenced by the recent introduction of shorts.
#
# 3.Shorts videos have a higher engagement rate (likes per total views) compared to normal videos, suggesting that users are more likely to engage with short-form content.
#
# 4.There is a positive correlation between views and likes count, indicating that as views increase, the number of likes also tends to increase.
#
# 5.There is a positive correlation between views and comments count, suggesting that higher views are associated with more comments.
#
# 6.There is a weak positive correlation between views and tags count, implying that the presence of tags may have a slight impact on views.
#
# 7.There is no clear relationship between video length and views count. Both short and normal videos can attract varying levels of views.
#
# 8.Videos uploaded on Saturdays and Sundays tend to get more views compared to other days, indicating that weekends are more favorable for viewership.
